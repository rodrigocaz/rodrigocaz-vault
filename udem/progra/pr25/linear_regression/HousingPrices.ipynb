# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
# Cargar el dataset desde la URL
url = 'https://github.com/adameubanks/LearnKeras/raw/master/1.LinearRegression/IowaHousingPrices.csv'
df = pd.read_csv(url)

# Ver las primeras filas del dataframe
print(df.head())
# Out:
#    SquareFeet  SalePrice
# 0        1710     208500
# 1        1262     181500
# 2        1786     223500
# 3        1717     140000
# 4        2198     250000

# %%
x = df[['SquareFeet']].values #x value
y = df[['SalePrice']].values #y value

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print(f"Tamaño del conjunto de entrenamiento: {X_train.shape}")
print(f"Tamaño del conjunto de prueba: {X_test.shape}")
# Out:
# Tamaño del conjunto de entrenamiento: (1168, 1)
# Tamaño del conjunto de prueba: (292, 1)

# %%
# Crear y entrenar el modelo
modelo = LinearRegression()
modelo.fit(X_train, y_train)

# Mostrar coeficientes
print(f"Pendiente (m): {modelo.coef_[0]}")
print(f"Intersección (b): {modelo.intercept_}")
# Out:
# Pendiente (m): [102.48895892]
# Intersección (b): [24899.74815734]

# %%
y_pred = modelo.predict(X_train)

# Calcular métricas de error
mae = mean_absolute_error(y_train, y_pred)
mse = mean_squared_error(y_train, y_pred)
rmse = np.sqrt(mse)

print(f"MAE train: {mae}")
print(f"MSE train: {mse}")
print(f"RMSE train: {rmse}")
# Out:
# MAE train: 37328.73928647853
# MSE train: 3078116053.8581204
# RMSE train: 55480.7719291839

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Hacer predicciones en el conjunto de prueba
y_pred = modelo.predict(X_test)

# Calcular métricas de error
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print(f"Error Absoluto Medio (MAE): {mae}")
print(f"Error Cuadrático Medio (MSE): {mse}")
print(f"Raíz del Error Cuadrático Medio (RMSE): {rmse}")
# Out:
# Error Absoluto Medio (MAE): 38341.20447642106
# Error Cuadrático Medio (MSE): 3418946311.1808047
# Raíz del Error Cuadrático Medio (RMSE): 58471.75652552953

# %%
import matplotlib.pyplot as plt

plt.scatter(X_test, y_test, color='blue', label='Actual')
plt.plot(X_test, y_pred, color='red', label='Predicted')
plt.xlabel('Square Feet')
plt.ylabel('Sale Price')
plt.legend()
plt.show()
